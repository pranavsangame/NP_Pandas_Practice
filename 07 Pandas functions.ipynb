# %% [markdown]
# # Slicing

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ## simple slicing

# %% [raw]
# It accesses the actual values at the index & columns

# %%
df[0:3]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
df[-5:]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df[80:91]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 80  81            5.5           2.4            3.8           1.1
# 81  82            5.5           2.4            3.7           1.0
# 82  83            5.8           2.7            3.9           1.2
# 83  84            6.0           2.7            5.1           1.6
# 84  85            5.4           3.0            4.5           1.5
# 85  86            6.0           3.4            4.5           1.6
# 86  87            6.7           3.1            4.7           1.5
# 87  88            6.3           2.3            4.4           1.3
# 88  89            5.6           3.0            4.1           1.3
# 89  90            5.5           2.5            4.0           1.3
# 90  91            5.5           2.6            4.4           1.2
#
#             Species
# 80  Iris-versicolor
# 81  Iris-versicolor
# 82  Iris-versicolor
# 83  Iris-versicolor
# 84  Iris-versicolor
# 85  Iris-versicolor
# 86  Iris-versicolor
# ...

# %%
df[['SepalLengthCm']]
# Out:
#      SepalLengthCm
# 0            100.0
# 1            200.0
# 2            300.0
# 3              4.6
# 4              5.0
# ..             ...
# 145            6.7
# 146            6.3
# 147            6.5
# 148            6.2
# 149            5.9
#
# [150 rows x 1 columns]

# %%
df[['SepalLengthCm','PetalWidthCm']]
# Out:
#      SepalLengthCm  PetalWidthCm
# 0              5.1           0.2
# 1              4.9           0.2
# 2              4.7           0.2
# 3              4.6           0.2
# 4              5.0           0.2
# ..             ...           ...
# 145            6.7           2.3
# 146            6.3           1.9
# 147            6.5           2.0
# 148            6.2           2.3
# 149            5.9           1.8
#
# [150 rows x 2 columns]

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.set_index('PetalLengthCm',inplace=True)

# %%
df[-5:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Float64Engine._maybe_get_bool_indexer()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: -5
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df[1:6]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-f36b6234cca8> in <module>
# ----> 1 df[1:6]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2997
#    2998         # Do we have a slicer (on rows)?
# -> 2999         indexer = convert_to_index_sliceable(self, key)
#    3000         if indexer is not None:
#    3001             if isinstance(indexer, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in convert_to_index_sliceable(obj, key)
#    2208     idx = obj.index
#    2209     if isinstance(key, slice):
# -> 2210         return idx._convert_slice_indexer(key, kind="getitem")
#    2211
#    2212     elif isinstance(key, str):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\numeric.py in _convert_slice_indexer(self, key, kind)
#     377         # We always treat __getitem__ slicing as label-based
# ...

# %%
df[1:3]
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalWidthCm          Species
# PetalLengthCm
# 1.0            23            4.6           3.6           0.2      Iris-setosa
# 1.7            24            5.1           3.3           0.5      Iris-setosa
# 1.9            25            4.8           3.4           0.2      Iris-setosa
# 1.6            26            5.0           3.0           0.2      Iris-setosa
# 1.6            27            5.0           3.4           0.4      Iris-setosa
# ...            ..            ...           ...           ...              ...
# 4.2            95            5.6           2.7           1.3  Iris-versicolor
# 4.2            96            5.7           3.0           1.2  Iris-versicolor
# 4.2            97            5.7           2.9           1.3  Iris-versicolor
# 4.3            98            6.2           2.9           1.3  Iris-versicolor
# 3.0            99            5.1           2.5           1.1  Iris-versicolor
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df[10:20][['SepalLengthCm','SepalWidthCm']]
# Out:
#     SepalLengthCm  SepalWidthCm
# 10            5.4           3.7
# 11            4.8           3.4
# 12            4.8           3.0
# 13            4.3           3.0
# 14            5.8           4.0
# 15            5.7           4.4
# 16            5.4           3.9
# 17            5.1           3.5
# 18            5.7           3.8
# 19            5.1           3.8

# %%
df[['SepalLengthCm','SepalWidthCm']][10:15]
# Out:
#     SepalLengthCm  SepalWidthCm
# 10            5.4           3.7
# 11            4.8           3.4
# 12            4.8           3.0
# 13            4.3           3.0
# 14            5.8           4.0

# %% [markdown]
# # loc function

# %% [raw]
# It also accesses the actual values at the index & columns

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.loc[2:5]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa

# %%
df.loc[:,['PetalLengthCm','PetalWidthCm']]
# Out:
#      PetalLengthCm  PetalWidthCm
# 0              1.4           0.2
# 1              1.4           0.2
# 2              1.3           0.2
# 3              1.5           0.2
# 4              1.4           0.2
# ..             ...           ...
# 145            5.2           2.3
# 146            5.0           1.9
# 147            5.2           2.0
# 148            5.4           2.3
# 149            5.1           1.8
#
# [150 rows x 2 columns]

# %%
df.loc[5:10,['PetalLengthCm','PetalWidthCm']]
# Out:
#     PetalLengthCm  PetalWidthCm
# 5             1.7           0.4
# 6             1.4           0.3
# 7             1.5           0.2
# 8             1.4           0.2
# 9             1.5           0.1
# 10            1.5           0.2

# %%
df.set_index('Species',inplace=True)

# %%
df
# Out:
#                  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa       1            5.1           3.5            1.4           0.2
# Iris-setosa       2            4.9           3.0            1.4           0.2
# Iris-setosa       3            4.7           3.2            1.3           0.2
# Iris-setosa       4            4.6           3.1            1.5           0.2
# Iris-setosa       5            5.0           3.6            1.4           0.2
# ...             ...            ...           ...            ...           ...
# Iris-virginica  146            6.7           3.0            5.2           2.3
# Iris-virginica  147            6.3           2.5            5.0           1.9
# Iris-virginica  148            6.5           3.0            5.2           2.0
# Iris-virginica  149            6.2           3.4            5.4           2.3
# Iris-virginica  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
df.loc['Iris-setosa':'Iris-virginica']
# Out:
#                  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa       1            5.1           3.5            1.4           0.2
# Iris-setosa       2            4.9           3.0            1.4           0.2
# Iris-setosa       3            4.7           3.2            1.3           0.2
# Iris-setosa       4            4.6           3.1            1.5           0.2
# Iris-setosa       5            5.0           3.6            1.4           0.2
# ...             ...            ...           ...            ...           ...
# Iris-virginica  146            6.7           3.0            5.2           2.3
# Iris-virginica  147            6.3           2.5            5.0           1.9
# Iris-virginica  148            6.5           3.0            5.2           2.0
# Iris-virginica  149            6.2           3.4            5.4           2.3
# Iris-virginica  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
df = df.reset_index()
df.columns
# Out:
# Index(['index', 'Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm',
#        'PetalWidthCm', 'Species'],
#       dtype='object')

# %%
#changing the sequence of the column
df = df[['Id','SepalLengthCm', 'SepalWidthCm','PetalLengthCm', 'PetalWidthCm','Species']]
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.loc[1:5,:]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa

# %% [markdown]
# ## iloc

# %% [raw]
# axes numbers have to passes for index & columns

# %%
df.iloc[:,:]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.iloc[1:5,:]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.iloc[1:5,1:3]
# Out:
#    SepalLengthCm  SepalWidthCm
# 1            4.9           3.0
# 2            4.7           3.2
# 3            4.6           3.1
# 4            5.0           3.6

# %%
df.set_index('Species',inplace=True)

# %%
df.iloc[0:5,2:5]
# Out:
#              SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa           3.5            1.4           0.2
# Iris-setosa           3.0            1.4           0.2
# Iris-setosa           3.2            1.3           0.2
# Iris-setosa           3.1            1.5           0.2
# Iris-setosa           3.6            1.4           0.2

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.iloc[-5:,-1:]
# Out:
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.iloc[1:30:2]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1    2          200.0           3.0            1.4           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 11  12            4.8           3.4            2.6           0.2  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa
# 19  20            5.1           3.8            1.5           0.3  Iris-setosa
# 21  22            5.1           3.7            1.5           0.4  Iris-setosa
# ...

# %%
df.iloc[:,1:5:2]
# Out:
#      SepalLengthCm  PetalLengthCm
# 0              5.1            1.4
# 1              4.9            1.4
# 2              4.7            1.3
# 3              4.6            1.5
# 4              5.0            1.4
# ..             ...            ...
# 145            6.7            5.2
# 146            6.3            5.0
# 147            6.5            5.2
# 148            6.2            5.4
# 149            5.9            5.1
#
# [150 rows x 2 columns]

# %%
dummy_df = df.iloc[5:15:3,1:5:2]
dummy_df
# Out:
#     SepalLengthCm  PetalLengthCm
# 5             5.4            1.7
# 8             4.4            1.4
# 11            4.8            1.6
# 14            5.8            1.2

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
x = df.iloc[1:30:2]
x[['SepalLengthCm']]
# Out:
#     SepalLengthCm
# 1             4.9
# 3             4.6
# 5             5.4
# 7             5.0
# 9             4.9
# 11            4.8
# 13            4.3
# 15            5.7
# 17            5.1
# 19            5.1
# 21            5.1
# 23            5.1
# 25            5.0
# 27            5.2
# 29            4.7

# %%
df.iloc[1:30:2][['SepalLengthCm']]
# Out:
#     SepalLengthCm
# 1             4.9
# 3             4.6
# 5             5.4
# 7             5.0
# 9             4.9
# 11            4.8
# 13            4.3
# 15            5.7
# 17            5.1
# 19            5.1
# 21            5.1
# 23            5.1
# 25            5.0
# 27            5.2
# 29            4.7

# %%
df[['SepalLengthCm']].iloc[5:10]
# Out:
#    SepalLengthCm
# 5            5.4
# 6            4.6
# 7            5.0
# 8            4.4
# 9            4.9

# %%
df.iloc[5:6,1:2]
# Out:
#    SepalLengthCm
# 5            5.4

# %%
df.iloc[[5],[1]]
# Out:
#    SepalLengthCm
# 5            5.4

# %%
df.iloc[5,1]
# Out:
# 5.4

# %%
df.iloc[11,3]
# Out:
# 1.6

# %% [markdown]
# #### replacing values in dataframe using loc & iloc function

# %%
df.loc[11,['PetalLengthCm']] = 1000
df.loc[[11]]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 11  12            4.8           3.4         1000.0           0.2  Iris-setosa

# %%
df.iloc[11,3] = 2.6
df.iloc[[11]]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 11  12            4.8           3.4            2.6           0.2  Iris-setosa

# %%
df.iloc[:3,1:2] = np.array([100,200,300])
df.iloc[:3,1:2]
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1          100.0           3.5            1.4           0.2
# 1      2          200.0           3.0            1.4           0.2
# 2      3          300.0           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df['SepalLengthCm']=np.random.randint(10,99,150)
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1             36           3.5            1.4           0.2
# 1      2             17           3.0            1.4           0.2
# 2      3             36           3.2            1.3           0.2
# 3      4             22           3.1            1.5           0.2
# 4      5             88           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146             66           3.0            5.2           2.3
# 146  147             66           2.5            5.0           1.9
# 147  148             66           3.0            5.2           2.0
# 148  149             84           3.4            5.4           2.3
# 149  150             62           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
np.random.randint(10,100,[150,2])
# Out:
# array([[81, 41],
#        [83, 44],
#        [39, 80],
#        [54, 34],
#        [63, 85],
#        [10, 72],
#        [92, 96],
#        [97, 49],
#        [56, 94],
#        [22, 38],
#        [24, 52],
#        [48, 25],
#        [61, 64],
#        [51, 98],
#        [64, 21],
#        [42, 59],
#        [58, 16],
#        [77, 54],
#        [18, 98],
#        [59, 72],
#        [12, 43],
#        [82, 63],
#        [46, 77],
#        [95, 38],
#        [62, 45],
#        [65, 64],
#        [37, 21],
#        [65, 69],
#        [92, 89],
#        [87, 30],
#        [43, 65],
#        [83, 53],
#        [89, 18],
#        [92, 29],
#        [15, 44],
#        [82, 32],
#        [44, 93],
#        [44, 11],
#        [75, 57],
#        [45, 86],
#        [63, 47],
#        [62, 54],
#        [69, 70],
#        [62, 82],
#        [91, 32],
#        [28, 56],
#        [89, 24],
#        [33, 48],
#        [44, 79],
#        [33, 64],
#        [35, 91],
#        [36, 23],
# ...

# %%
df.iloc[:3,1:3]=[[1,2],
                 [3,4],
                 [6,7]]
df.iloc[:,1:3]=np.random.randint(10,100,[150,2])
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1             14            67            1.4           0.2
# 1      2             51            56            1.4           0.2
# 2      3             67            28            1.3           0.2
# 3      4             95            30            1.5           0.2
# 4      5             74            30            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146             83            81            5.2           2.3
# 146  147             62            90            5.0           1.9
# 147  148             88            74            5.2           2.0
# 148  149             53            26            5.4           2.3
# 149  150             37            26            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # type & dtype function

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['SepalLengthCm'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm      int64
# SepalWidthCm       int64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df['PetalWidthCm'].dtype
# Out:
# dtype('float64')

# %%
df['Species'].dtype
# Out:
# dtype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    int64
#  2   SepalWidthCm   150 non-null    int64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(2), int64(3), object(1)
# memory usage: 7.2+ KB
