# %%
import pandas as pd
import numpy as np

df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.Gender.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.Gender.value_counts()
# Out:
# male      577
# female    314
# Name: Gender, dtype: int64

# %%
df.loc[(df.Gender=='male')&(df.Survived==1)]#.shape[0]
#df[110:112]
df.loc[df.Survived==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[(df.Gender=='female')&(df.Survived==1)].shape[0]
# Out:
# 233

# %% [markdown]
# ## dtype function

# %%
df.Gender.dtype
# Out:
# dtype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## astype function

# %%
df.Pclass=df.Pclass.astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    float64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 83.7+ KB

# %%
dft = pd.DataFrame({'A':np.random.randint(10,20,5),'B':[10,20,30,40,50]})
dft
# Out:
#     A   B
# 0  19  10
# 1  18  20
# 2  17  30
# 3  16  40
# 4  11  50

# %%
dft['C']='Python'
dft
# Out:
#     A   B       C
# 0  19  10  Python
# 1  18  20  Python
# 2  17  30  Python
# 3  16  40  Python
# 4  11  50  Python

# %%
dft['D']=dft['A']+dft['B']
dft
# Out:
#     A   B       C   D
# 0  19  10  Python  29
# 1  18  20  Python  38
# 2  17  30  Python  47
# 3  16  40  Python  56
# 4  11  50  Python  61

# %%
dft['D']=dft['D'].astype('str')
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       5 non-null      int32
#  1   B       5 non-null      int64
#  2   C       5 non-null      object
#  3   D       5 non-null      object
# dtypes: int32(1), int64(1), object(2)
# memory usage: 268.0+ bytes

# %%
dft['D']=dft['D']+'%'
dft
# Out:
#     A   B       C    D
# 0  19  10  Python  29%
# 1  18  20  Python  38%
# 2  17  30  Python  47%
# 3  16  40  Python  56%
# 4  11  50  Python  61%

# %% [markdown]
# # insert()

# %% [raw]
# syntax:
#     df.insert(column_location_index,New_column_name,New_column_values)

# %%
df=dft.copy()
df
# Out:
#     A   B       C    D
# 0  19  10  Python  29%
# 1  18  20  Python  38%
# 2  17  30  Python  47%
# 3  16  40  Python  56%
# 4  11  50  Python  61%

# %%
df.insert(1,'X',[-1,-2,-3,-4,-5])

# %%
df
# Out:
#     A  X   B       C    D
# 0  19 -1  10  Python  29%
# 1  18 -2  20  Python  38%
# 2  17 -3  30  Python  47%
# 3  16 -4  40  Python  56%
# 4  11 -5  50  Python  61%

# %%
df.insert(5,'Z',1000)

# %%
df
# Out:
#     A  X   B       C    D     Z
# 0  19 -1  10  Python  29%  1000
# 1  18 -2  20  Python  38%  1000
# 2  17 -3  30  Python  47%  1000
# 3  16 -4  40  Python  56%  1000
# 4  11 -5  50  Python  61%  1000

# %%
df[['A','B','C','D','X','Z']]
# Out:
#     A   B       C    D  X     Z
# 0  19  10  Python  29% -1  1000
# 1  18  20  Python  38% -2  1000
# 2  17  30  Python  47% -3  1000
# 3  16  40  Python  56% -4  1000
# 4  11  50  Python  61% -5  1000

# %%
df.T
# Out:
#         0       1       2       3       4
# A      19      18      17      16      11
# X      -1      -2      -3      -4      -5
# B      10      20      30      40      50
# C  Python  Python  Python  Python  Python
# D     29%     38%     47%     56%     61%
# Z    1000    1000    1000    1000    1000

# %%
df = (df.T)
df.insert(5,5,[15,-6,60,'Python','39%',1000])
df = df.T
df
# Out:
#     A   X   B       C    D     Z
# 0  19  -1  10  Python  29%  1000
# 1  18  -2  20  Python  38%  1000
# 2  17  -3  30  Python  47%  1000
# 3  16  -4  40  Python  56%  1000
# 4  11  -5  50  Python  61%  1000
# 5  15  -6  60  Python  39%  1000

# %% [markdown]
# # rename

# %%
df.rename({'A':'a'},inplace=True,axis=1)
df
# Out:
#     a   X   B       C    D     Z
# 0  15  -1  10  Python  25%  1000
# 1  11  -2  20  Python  31%  1000
# 2  13  -3  30  Python  43%  1000
# 3  12  -4  40  Python  52%  1000
# 4  11  -5  50  Python  61%  1000
# 5  15  -6  60  Python  39%  1000

# %%
df.rename({'C':'c','B':'b'},inplace=True,axis=1)
df
# Out:
#     a   X   b       c    D     Z
# 0  15  -1  10  Python  25%  1000
# 1  11  -2  20  Python  31%  1000
# 2  13  -3  30  Python  43%  1000
# 3  12  -4  40  Python  52%  1000
# 4  11  -5  50  Python  61%  1000
# 5  15  -6  60  Python  39%  1000

# %%
df.rename({1:'hi',2:'bye'},inplace=True,axis=0)
df
# Out:
#       a   X   b       c    D     Z
# 0    15  -1  10  Python  25%  1000
# hi   11  -2  20  Python  31%  1000
# bye  13  -3  30  Python  43%  1000
# 3    12  -4  40  Python  52%  1000
# 4    11  -5  50  Python  61%  1000
# 5    15  -6  60  Python  39%  1000

# %%
df = df.rename({0:-1})
df
# Out:
#       a   X   b       c    D     Z
# -1   15  -1  10  Python  25%  1000
# hi   11  -2  20  Python  31%  1000
# bye  13  -3  30  Python  43%  1000
# 3    12  -4  40  Python  52%  1000
# 4    11  -5  50  Python  61%  1000
# 5    15  -6  60  Python  39%  1000

# %% [markdown]
# # shifting the values along row or column

# %% [markdown]
# ### rowise shift by default axis is 0

# %%
df
dfy = df.shift(2)    
dfy
# Out:
#      A    X    B       C    D     Z
# 0  NaN  NaN  NaN     NaN  NaN   NaN
# 1  NaN  NaN  NaN     NaN  NaN   NaN
# 2   19   -1   10  Python  29%  1000
# 3   18   -2   20  Python  38%  1000
# 4   17   -3   30  Python  47%  1000
# 5   16   -4   40  Python  56%  1000

# %%
dfy = df.shift(-1,axis=0)
dfy
# Out:
#      A    X    B       C    D     Z
# 0   18   -2   20  Python  38%  1000
# 1   17   -3   30  Python  47%  1000
# 2   16   -4   40  Python  56%  1000
# 3   11   -5   50  Python  61%  1000
# 4   15   -6   60  Python  39%  1000
# 5  NaN  NaN  NaN     NaN  NaN   NaN

# %% [markdown]
# ### columnwise shifting

# %%
dfy = df.shift(2,axis=1)
dfy
# Out:
#        a    X   b   c   D       Z
# -1   NaN  NaN  15  -1  10  Python
# hi   NaN  NaN  11  -2  20  Python
# bye  NaN  NaN  13  -3  30  Python
# 3    NaN  NaN  12  -4  40  Python
# 4    NaN  NaN  11  -5  50  Python
# 5    NaN  NaN  15  -6  60  Python

# %%
dfy = df.shift(-2,axis=1)
dfy
# Out:
#     A       X    B     C    D    Z
# 0  10  Python  29%  1000  NaN  NaN
# 1  20  Python  38%  1000  NaN  NaN
# 2  30  Python  47%  1000  NaN  NaN
# 3  40  Python  56%  1000  NaN  NaN
# 4  50  Python  61%  1000  NaN  NaN
# 5  60  Python  39%  1000  NaN  NaN

# %%
dft.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
dft
# Out:
#     A   B
# 0  18  10
# 1  18  20
# 2  10  30
# 3  18  40
# 4  13  50

# %%
dft.index=dft.index+1
dft
# Out:
#     A   B
# 1  18  10
# 2  18  20
# 3  10  30
# 4  18  40
# 5  13  50
