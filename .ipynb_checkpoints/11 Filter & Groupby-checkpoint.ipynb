# %%
import pandas as pd
import numpy as np

df = pd.read_csv('movies_data.csv')
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
len(df.genre.unique())
# Out:
# 16

# %%
df.genre.nunique()
# Out:
# 16

# %%
df.content_rating.unique()
# Out:
# array(['R', 'PG-13', 'NOT RATED', 'PG', 'UNRATED', 'APPROVED', 'PASSED',
#        'G', 'X', nan, 'TV-MA', 'GP', 'NC-17'], dtype=object)

# %%
df.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
for x in df.columns:
    print(f"x >> {x}",df[x].unique(),sep="\n\n")
    print(' ')
# Out:
# x >> star_rating
#
# [9.3 9.2 9.1 9.  8.9 8.8 8.7 8.6 8.5 8.4 8.3 8.2 8.1 8.  7.9 7.8 7.7 7.6
#  7.5 7.4]
#
# x >> title
#
# ['The Shawshank Redemption' 'The Godfather' 'The Godfather: Part II'
#  'The Dark Knight' 'Pulp Fiction' '12 Angry Men'
#  'The Good, the Bad and the Ugly'
#  'The Lord of the Rings: The Return of the King' "Schindler's List"
#  'Fight Club' 'The Lord of the Rings: The Fellowship of the Ring'
#  'Inception' 'Star Wars: Episode V - The Empire Strikes Back'
#  'Forrest Gump' 'The Lord of the Rings: The Two Towers' 'Interstellar'
#  "One Flew Over the Cuckoo's Nest" 'Seven Samurai' 'Goodfellas'
#  'Star Wars' 'The Matrix' 'City of God' "It's a Wonderful Life"
#  'The Usual Suspects' 'Se7en' 'Life Is Beautiful'
#  'Once Upon a Time in the West' 'The Silence of the Lambs'
#  'Leon: The Professional' 'City Lights' 'Spirited Away' 'The Intouchables'
#  'Casablanca' 'Whiplash' 'American History X' 'Modern Times'
# ...

# %%
df.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
df.content_rating.value_counts()
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# PASSED         7
# NC-17          7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %% [markdown]
# # groupby

# %%
df.groupby('genre')

# %%
from termcolor import colored


for genre,subdf in df.groupby('genre'):
    print(colored(genre,color='red',attrs=['bold']))
    display(subdf)
# Out:
# Action
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
df.groupby('genre').first()
# Out:
#            star_rating                                          title  \
# genre
# Action             9.0                                The Dark Knight
# Adventure          8.9  The Lord of the Rings: The Return of the King
# Animation          8.6                                  Spirited Away
# Biography          8.9                               Schindler's List
# Comedy             8.6                              Life Is Beautiful
# Crime              9.3                       The Shawshank Redemption
# Drama              8.9                                   12 Angry Men
# Family             7.9                     E.T. the Extra-Terrestrial
# Fantasy            7.7                      The City of Lost Children
# Film-Noir          8.3                                  The Third Man
# History            8.0                            Battleship Potemkin
# Horror             8.6                                         Psycho
# ...

# %%
df.groupby('genre').last()
# Out:
#            star_rating                                            title  \
# genre
# Action             7.4  Master and Commander: The Far Side of the World
# Adventure          7.4                      Back to the Future Part III
# Animation          7.4                               The Simpsons Movie
# Biography          7.4                                          Lincoln
# Comedy             7.4                                          Tootsie
# Crime              7.4                                      Wall Street
# Drama              7.4                            The Cider House Rules
# Family             7.8              Willy Wonka & the Chocolate Factory
# Fantasy            7.7                        The City of Lost Children
# Film-Noir          7.7                                       Spellbound
# History            8.0                              Battleship Potemkin
# Horror             7.4                                      Poltergeist
# ...

# %%
df.groupby('genre').get_group('Adventure')
# Out:
#      star_rating                                              title  \
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 14           8.8              The Lord of the Rings: The Two Towers
# 15           8.7                                       Interstellar
# 54           8.5                                 Back to the Future
# ..           ...                                                ...
# 936          7.4                                          True Grit
# 937          7.4                                          Labyrinth
# 943          7.4                                    The Bucket List
# 953          7.4                              The NeverEnding Story
# 975          7.4                        Back to the Future Part III
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 10           PG-13  Adventure       178
# ...

# %%
df.groupby('genre').get_group('Adventure')['genre'].unique()
# Out:
# array(['Adventure'], dtype=object)

# %%
df.groupby('content_rating').get_group('R')
# Out:
#      star_rating                     title content_rating      genre  \
# 0            9.3  The Shawshank Redemption              R      Crime
# 1            9.2             The Godfather              R      Crime
# 2            9.1    The Godfather: Part II              R      Crime
# 4            8.9              Pulp Fiction              R      Crime
# 8            8.9          Schindler's List              R  Biography
# ..           ...                       ...            ...        ...
# 968          7.4       The English Patient              R      Drama
# 969          7.4       Law Abiding Citizen              R      Crime
# 970          7.4               Wonder Boys              R      Drama
# 971          7.4        Death at a Funeral              R     Comedy
# 978          7.4               Wall Street              R      Crime
#
#      duration                                        actors_list
# 0         142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# ...

# %%
df.groupby(['content_rating','genre']).get_group(('R','Crime'))
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
df.groupby(['content_rating','genre']).sum().reset_index()
# Out:
#    content_rating      genre  star_rating  duration
# 0        APPROVED     Action         22.9       430
# 1        APPROVED  Adventure         24.3       475
# 2        APPROVED  Animation         22.8       254
# 3        APPROVED  Biography          7.9       111
# 4        APPROVED     Comedy         72.8       975
# ..            ...        ...          ...       ...
# 90        UNRATED    Mystery          7.9        86
# 91              X     Comedy          7.8        84
# 92              X      Crime          8.4       136
# 93              X      Drama          8.0       113
# 94              X     Horror          7.5        92
#
# [95 rows x 4 columns]

# %%
df.groupby(['content_rating','genre'])['duration'].sum()
# Out:
# content_rating  genre
# APPROVED        Action       430
#                 Adventure    475
#                 Animation    254
#                 Biography    111
#                 Comedy       975
#                             ...
# UNRATED         Mystery       86
# X               Comedy        84
#                 Crime        136
#                 Drama        113
#                 Horror        92
# Name: duration, Length: 95, dtype: int64

# %%
df.groupby(['content_rating','genre'])['duration'].sum().reset_index()
# Out:
#    content_rating      genre  duration
# 0        APPROVED     Action       430
# 1        APPROVED  Adventure       475
# 2        APPROVED  Animation       254
# 3        APPROVED  Biography       111
# 4        APPROVED     Comedy       975
# ..            ...        ...       ...
# 90        UNRATED    Mystery        86
# 91              X     Comedy        84
# 92              X      Crime       136
# 93              X      Drama       113
# 94              X     Horror        92
#
# [95 rows x 3 columns]

# %%
df.loc[df['genre']=='Crime']
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
df.loc[(df['genre']=='Crime')&(df['content_rating']=='PG')]
# Out:
#      star_rating                  title content_rating  genre  duration  \
# 154          8.2         Cool Hand Luke             PG  Crime       126
# 171          8.2      Dial M for Murder             PG  Crime       105
# 200          8.1            Le Samourai             PG  Crime       101
# 297          8.0                   Rope             PG  Crime        80
# 425          7.9               Badlands             PG  Crime        94
# 495          7.8  The Day of the Jackal             PG  Crime       143
#
#                                            actors_list
# 154  [u'Paul Newman', u'George Kennedy', u'Strother...
# 171  [u'Ray Milland', u'Grace Kelly', u'Robert Cumm...
# 200  [u'Alain Delon', u'Nathalie Delon', u'Fran\xe7...
# 297  [u'James Stewart', u'John Dall', u'Farley Gran...
# 425  [u'Martin Sheen', u'Sissy Spacek', u'Warren Oa...
# 495  [u'Edward Fox', u'Terence Alexander', u'Michel...

# %%
df.loc[(df['genre']=='Crime')|(df['content_rating']=='PG')]
# Out:
#      star_rating                                           title  \
# 0            9.3                        The Shawshank Redemption
# 1            9.2                                   The Godfather
# 2            9.1                          The Godfather: Part II
# 4            8.9                                    Pulp Fiction
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# ..           ...                                             ...
# 969          7.4                             Law Abiding Citizen
# 974          7.4                                         Tootsie
# 975          7.4                     Back to the Future Part III
# 977          7.4                                     Poltergeist
# 978          7.4                                     Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.loc[((df['genre']=='Crime')&(df['content_rating']=='PG'))|((df['genre']=='Adventure')&(df['content_rating']=='R'))]
# Out:
#      star_rating                                    title content_rating  \
# 68           8.4                                 Das Boot              R
# 114          8.3                     Inglourious Basterds              R
# 154          8.2                           Cool Hand Luke             PG
# 164          8.2                            Into the Wild              R
# 171          8.2                        Dial M for Murder             PG
# 200          8.1                              Le Samourai             PG
# 206          8.1                              Stand by Me              R
# 214          8.1                 The Grand Budapest Hotel              R
# 297          8.0                                     Rope             PG
# 309          8.0                            Blood Diamond              R
# 424          7.9                          The Right Stuff              R
# 425          7.9                                 Badlands             PG
# ...

# %%
df.loc[(df['star_rating']<9.0)|(df['star_rating']>8.1)]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.loc[(df['star_rating']>9.0)&(df['duration']>150)]
# Out:
#    star_rating                   title content_rating  genre  duration  \
# 1          9.2           The Godfather              R  Crime       175
# 2          9.1  The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
df.loc[~((df['star_rating']>9.0)|(df['duration']>150))]
# Out:
#      star_rating                                            title  \
# 5            8.9                                     12 Angry Men
# 9            8.9                                       Fight Club
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                     Forrest Gump
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 5        NOT RATED      Drama        96
# 9                R      Drama       139
# 11           PG-13     Action       148
# ...

# %% [markdown]
# # isin function pandas

# %%
data = pd.read_csv("employees.csv")
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_59092/3503987057.py in <module>
# ----> 1 data = pd.read_csv("employees.csv")
#       2 data
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# making data frame from csv file

  
# creating a bool series from isin()
new = data["Gender"].isin(["Male"])
  
# displaying data with gender = male only
data.loc[new]

# %%
list1 = ['Male',np.NaN]

data.loc[data["Gender"].isin(list1)]

# %%
data.loc[data['Gender']=='Male']

# %% [markdown]
# ### not in operator  (~)

# %%
data.loc[~(data['Gender']=='Male')]

# %%
data.loc[~((data['Gender']=='Male')|(data['Gender']=='Female'))]

# %%
data.loc[np.where(data['Gender']=='Male')]

# %%
data[new].Gender.unique()

# %%
data1 = pd.DataFrame({'name': ['sravan', 'harsha', 'jyothika'],
                      'subject1': ['python', 'R', 'php'],
                      'marks': [96, 89, 90]}, index=[0, 1, 2])
display(data1)  

list1 = ['harsha', 'jyothika', 96]
  

data1.loc[~data1[['name', 'marks']].isin(list1).any(axis=1)]

# %%
list2 = ['R', 'sravan']
  

data1[~data1[['subject1', 'name']].isin(list2).any(axis=1)]

# %% [markdown]
# # group by functions

# %%
data = {'Name':['Jai','Anuj','Jai','Princi','Gaurav','Anuj','Princi','Abhi','Anuj'],
       'Age':[27,24,22,32,33,29,27,32,32],
       'Address':['Nagpur','Pune','Kanpur','Allahabad','Jodhpur','Kanpur','Allahabad','Aligarh','Pune'],
       'Qualification':['Msc','MA','MCA','PHD','BE','B.com','Msc','MA','B.com'],
       'Score':[24,24,35,45,53,47,50,52,60]}

df = pd.DataFrame(data)
df
# Out:
#      Name  Age    Address Qualification  Score
# 0     Jai   27     Nagpur           Msc     24
# 1    Anuj   24       Pune            MA     24
# 2     Jai   22     Kanpur           MCA     35
# 3  Princi   32  Allahabad           PHD     45
# 4  Gaurav   33    Jodhpur            BE     53
# 5    Anuj   29     Kanpur         B.com     47
# 6  Princi   27  Allahabad           Msc     50
# 7    Abhi   32    Aligarh            MA     52
# 8    Anuj   32       Pune         B.com     60

# %% [markdown]
# ## groups function in groupby

# %%
df.groupby('Name').groups
# Out:
# {'Abhi': [7], 'Anuj': [1, 5, 8], 'Gaurav': [4], 'Jai': [0, 2], 'Princi': [3, 6]}

# %%
df.groupby('Address').groups
# Out:
# {'Aligarh': [7], 'Allahabad': [3, 6], 'Jodhpur': [4], 'Kanpur': [2, 5], 'Nagpur': [0], 'Pune': [1, 8]}

# %% [markdown]
# ## ngroups in groupby

# %%
df.groupby('Name').ngroups
# Out:
# 5

# %%
df.groupby('Address').ngroups
# Out:
# 6

# %% [markdown]
# ## size in groupby

# %%
df.groupby('Name').size()
# Out:
# Name
# Abhi      1
# Anuj      3
# Gaurav    1
# Jai       2
# Princi    2
# dtype: int64

# %% [markdown]
# ## sort in groupby

# %%
df.groupby(['Score'],sort=True).mean('Age')  #by default sort is True gives output of grouby in sorted order
# Out:
#         Age
# Score
# 24     25.5
# 35     22.0
# 45     32.0
# 47     29.0
# 50     27.0
# 52     32.0
# 53     33.0
# 60     32.0

# %%
df.groupby(['Score'],sort=False).mean('Age') # is sort = false then it preserve the actual order of the column on which groupby is applied.
# Out:
#         Age
# Score
# 24     25.5
# 35     22.0
# 45     32.0
# 53     33.0
# 47     29.0
# 50     27.0
# 52     32.0
# 60     32.0

# %% [markdown]
# ## statistical functions on groupby

# %%
df.groupby(['Name'],sort=False).mean()
# Out:
#               Age      Score
# Name
# Jai     24.500000  29.500000
# Anuj    28.333333  43.666667
# Princi  29.500000  47.500000
# Gaurav  33.000000  53.000000
# Abhi    32.000000  52.000000

# %%
df.groupby(['Name'],sort=False).median()
# Out:
#          Age  Score
# Name
# Jai     24.5   29.5
# Anuj    29.0   47.0
# Princi  29.5   47.5
# Gaurav  33.0   53.0
# Abhi    32.0   52.0

# %%
df.groupby(['Name'],sort=False)['Age'].median().reset_index()
# Out:
#      Name   Age
# 0     Jai  24.5
# 1    Anuj  29.0
# 2  Princi  29.5
# 3  Gaurav  33.0
# 4    Abhi  32.0

# %%
df.groupby(['Name'],sort=False)['Age'].sum().reset_index()
# Out:
#      Name  Age
# 0     Jai   49
# 1    Anuj   85
# 2  Princi   59
# 3  Gaurav   33
# 4    Abhi   32

# %%
df.groupby(['Name'],sort=False)['Age'].min().reset_index()
# Out:
#      Name  Age
# 0     Jai   22
# 1    Anuj   24
# 2  Princi   27
# 3  Gaurav   33
# 4    Abhi   32

# %%
df.groupby(['Name'],sort=False)['Age'].max().reset_index()
# Out:
#      Name  Age
# 0     Jai   27
# 1    Anuj   32
# 2  Princi   32
# 3  Gaurav   33
# 4    Abhi   32

# %%
df.groupby(['Name'],sort=False)['Age'].count().reset_index()
# Out:
#      Name  Age
# 0     Jai    2
# 1    Anuj    3
# 2  Princi    2
# 3  Gaurav    1
# 4    Abhi    1

# %% [markdown]
# ## agg functions in groupby

# %%
df.groupby(['Name'])['Age'].agg(np.sum)
# Out:
# Name
# Abhi      32
# Anuj      85
# Gaurav    33
# Jai       49
# Princi    59
# Name: Age, dtype: int64

# %%
df.groupby(['Name'])['Age'].agg([np.sum,np.mean,np.median,np.std])
# Out:
#         sum       mean  median       std
# Name
# Abhi     32  32.000000    32.0       NaN
# Anuj     85  28.333333    29.0  4.041452
# Gaurav   33  33.000000    33.0       NaN
# Jai      49  24.500000    24.5  3.535534
# Princi   59  29.500000    29.5  3.535534

# %%
df.groupby(['Name'])['Address'].agg(pd.Series.mode).reset_index()
# Out:
#      Name           Address
# 0    Abhi           Aligarh
# 1    Anuj              Pune
# 2  Gaurav           Jodhpur
# 3     Jai  [Kanpur, Nagpur]
# 4  Princi         Allahabad

# %%
df.groupby(['Name'],sort=False)['Age'].mean().reset_index()
# Out:
#      Name        Age
# 0     Jai  24.500000
# 1    Anuj  28.333333
# 2  Princi  29.500000
# 3  Gaurav  33.000000
# 4    Abhi  32.000000

# %%
df.groupby(['Name']).agg({'Age':np.mean,'Qualification':'count'})
# Out:
#               Age  Qualification
# Name
# Abhi    32.000000              1
# Anuj    28.333333              3
# Gaurav  33.000000              1
# Jai     24.500000              2
# Princi  29.500000              2

# %%
df.groupby(['Name']).agg({'Age':'median','Name':'count'})
# Out:
#          Age  Name
# Name
# Abhi    32.0     1
# Anuj    29.0     3
# Gaurav  33.0     1
# Jai     24.5     2
# Princi  29.5     2

# %% [markdown]
# ## aggregate function in groupby

# %%
df
# Out:
#      Name  Age    Address Qualification  Score
# 0     Jai   27     Nagpur           Msc     24
# 1    Anuj   24       Pune            MA     24
# 2     Jai   22     Kanpur           MCA     35
# 3  Princi   32  Allahabad           PHD     45
# 4  Gaurav   33    Jodhpur            BE     53
# 5    Anuj   29     Kanpur         B.com     47
# 6  Princi   27  Allahabad           Msc     50
# 7    Abhi   32    Aligarh            MA     52
# 8    Anuj   32       Pune         B.com     60

# %%
df.groupby(['Name','Qualification']).aggregate(np.sum)
# Out:
#                       Age  Score
# Name   Qualification
# Abhi   MA              32     52
# Anuj   B.com           61    107
#        MA              24     24
# Gaurav BE              33     53
# Jai    MCA             22     35
#        Msc             27     24
# Princi Msc             27     50
#        PHD             32     45

# %%
df.groupby(['Name','Qualification']).aggregate(np.sum).reset_index()
# Out:
#      Name Qualification  Age  Score
# 0    Abhi            MA   32     52
# 1    Anuj         B.com   61    107
# 2    Anuj            MA   24     24
# 3  Gaurav            BE   33     53
# 4     Jai           MCA   22     35
# 5     Jai           Msc   27     24
# 6  Princi           Msc   27     50
# 7  Princi           PHD   32     45

# %% [markdown]
# # Apply function

# %%
df
# Out:
#      Name  Age    Address Qualification  Score
# 0     Jai   27     Nagpur           Msc     24
# 1    Anuj   24       Pune            MA     24
# 2     Jai   22     Kanpur           MCA     35
# 3  Princi   32  Allahabad           PHD     45
# 4  Gaurav   33    Jodhpur            BE     53
# 5    Anuj   29     Kanpur         B.com     47
# 6  Princi   27  Allahabad           Msc     50
# 7    Abhi   32    Aligarh            MA     52
# 8    Anuj   32       Pune         B.com     60

# %%
def add_2_in_age(variable):
    return variable+2

df['Age']=df['Age'].apply(add_2_in_age)
df
# Out:
#      Name  Age    Address Qualification  Score
# 0     Jai   29     Nagpur           Msc     24
# 1    Anuj   26       Pune            MA     24
# 2     Jai   24     Kanpur           MCA     35
# 3  Princi   34  Allahabad           PHD     45
# 4  Gaurav   35    Jodhpur            BE     53
# 5    Anuj   31     Kanpur         B.com     47
# 6  Princi   29  Allahabad           Msc     50
# 7    Abhi   34    Aligarh            MA     52
# 8    Anuj   34       Pune         B.com     60

# %%
def uppercase(var):
    return var.upper()

df['Qualification']=df['Qualification'].apply(uppercase)
df
# Out:
#      Name  Age    Address Qualification  Score
# 0     Jai   29     Nagpur           MSC     24
# 1    Anuj   26       Pune            MA     24
# 2     Jai   24     Kanpur           MCA     35
# 3  Princi   34  Allahabad           PHD     45
# 4  Gaurav   35    Jodhpur            BE     53
# 5    Anuj   31     Kanpur         B.COM     47
# 6  Princi   29  Allahabad           MSC     50
# 7    Abhi   34    Aligarh            MA     52
# 8    Anuj   34       Pune         B.COM     60

# %%
df
# Out:
#      Name  Age    Address Qualification  Score
# 0     Jai   29     Nagpur           MSC     24
# 1    Anuj   26       Pune            MA     24
# 2     Jai   24     Kanpur           MCA     35
# 3  Princi   34  Allahabad           PHD     45
# 4  Gaurav   35    Jodhpur            BE     53
# 5    Anuj   31     Kanpur         B.COM     47
# 6  Princi   29  Allahabad           MSC     50
# 7    Abhi   34    Aligarh            MA     52
# 8    Anuj   34       Pune         B.COM     60

# %%
df['Qualification']=df['Qualification'].apply(lambda x : x.upper())
df
# Out:
#      Name  Age    Address Qualification  Score
# 0     Jai   29     Nagpur           MSC     24
# 1    Anuj   26       Pune            MA     24
# 2     Jai   24     Kanpur           MCA     35
# 3  Princi   34  Allahabad           PHD     45
# 4  Gaurav   35    Jodhpur            BE     53
# 5    Anuj   31     Kanpur         B.COM     47
# 6  Princi   29  Allahabad           MSC     50
# 7    Abhi   34    Aligarh            MA     52
# 8    Anuj   34       Pune         B.COM     60

# %%
df['Qualification']=df['Qualification'].transform(lambda x : x.upper())
df
# Out:
#      Name  Age    Address Qualification  Score
# 0     Jai   29     Nagpur           MSC     24
# 1    Anuj   26       Pune            MA     24
# 2     Jai   24     Kanpur           MCA     35
# 3  Princi   34  Allahabad           PHD     45
# 4  Gaurav   35    Jodhpur            BE     53
# 5    Anuj   31     Kanpur         B.COM     47
# 6  Princi   29  Allahabad           MSC     50
# 7    Abhi   34    Aligarh            MA     52
# 8    Anuj   34       Pune         B.COM     60

# %%
df['Score_updated']=df['Score'].transform(lambda x :((x-x.min()/x.std())*10))
df
# Out:
#      Name  Age    Address Qualification  Score  Score_updated
# 0     Jai   29     Nagpur           MSC     24      221.34427
# 1    Anuj   26       Pune            MA     24      221.34427
# 2     Jai   24     Kanpur           MCA     35      331.34427
# 3  Princi   34  Allahabad           PHD     45      431.34427
# 4  Gaurav   35    Jodhpur            BE     53      511.34427
# 5    Anuj   31     Kanpur         B.COM     47      451.34427
# 6  Princi   29  Allahabad           MSC     50      481.34427
# 7    Abhi   34    Aligarh            MA     52      501.34427
# 8    Anuj   34       Pune         B.COM     60      581.34427

# %%
x=df.groupby('Name')['Age'].apply(lambda x : x+10).reset_index()
x#.drop('index',axis=1)
# Out:
#    index  Age
# 0      0   39
# 1      1   36
# 2      2   34
# 3      3   44
# 4      4   45
# 5      5   41
# 6      6   39
# 7      7   44
# 8      8   44

# %%
df.groupby('Name').apply(lambda x : x-x.mean())
# Out:
# C:\Users\Pranav\AppData\Local\Temp/ipykernel_59092/1099954357.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.groupby('Name').apply(lambda x : x-x.mean())
#   Address       Age Name Qualification      Score  Score_updated
# 0     NaN  2.500000  NaN           NaN  -5.500000     -55.000000
# 1     NaN -4.333333  NaN           NaN -19.666667    -196.666667
# 2     NaN -2.500000  NaN           NaN   5.500000      55.000000
# 3     NaN  2.500000  NaN           NaN  -2.500000     -25.000000
# 4     NaN  0.000000  NaN           NaN   0.000000       0.000000
# 5     NaN  0.666667  NaN           NaN   3.333333      33.333333
# 6     NaN -2.500000  NaN           NaN   2.500000      25.000000
# 7     NaN  0.000000  NaN           NaN   0.000000       0.000000
# ...

# %%
dfx = df.groupby('Name')['Age'].mean().reset_index()
dfx
# Out:
#      Name        Age
# 0    Abhi  34.000000
# 1    Anuj  30.333333
# 2  Gaurav  35.000000
# 3     Jai  26.500000
# 4  Princi  31.500000

# %%
dfx['Age']=dfx['Age'].apply(lambda x : x-10)
dfx
# Out:
#      Name        Age
# 0    Abhi  24.000000
# 1    Anuj  20.333333
# 2  Gaurav  25.000000
# 3     Jai  16.500000
# 4  Princi  21.500000

# %%
dfx['just'] = df['Score']*2
dfx
# Out:
#      Name        Age  just
# 0    Abhi  24.000000    48
# 1    Anuj  20.333333    48
# 2  Gaurav  25.000000    70
# 3     Jai  16.500000    90
# 4  Princi  21.500000   106
